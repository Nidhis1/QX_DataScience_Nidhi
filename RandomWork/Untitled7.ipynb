# %% [raw]
# import numpy as np
# a=np.array([(1,2,3),(4,5,6)])
# print(a)
# a=a.reshape(3,2)
# print(a)

# %%
import matplotlib.pyplot as plt
value1=[54,54,54,65]
value2=[54,54,65,84]
value3=[54,78,98,85]
value4=[87,58,98,75]
box_plot_data=[value1,value2,value3,value4]
plt.boxplot(box_plot_data,notch='False',patch_artist='True',labels=['course1','course2','course3','course4'])
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-59c6c18c40e8> in <module>
#       6 box_plot_data=[value1,value2,value3,value4]
#       7 plt.boxplot(box_plot_data,notch='False',patch_artist='True',labels=['course1','course2','course3','course4'])
# ----> 8 plot.show()
#
# NameError: name 'plot' is not defined
